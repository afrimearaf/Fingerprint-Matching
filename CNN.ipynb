# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Tue May  2 01:38:11 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
# Out:
# Name: /physical_device:GPU:0   Type: GPU

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-5-17bb7203622b>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
import numpy as np
import cv2
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
images = []
labels = []

# %%
# Load the FVC2000 dataset

train_dir = '/content/drive/MyDrive/Fingerprint/FVC2000_DB4_B/dataset/train_data'
for j in range(0, 10):
    for k in range(0, 80):
        path = '0000' + str(j) + '_';
        if k <= 9:
            path = path + '0';
        path = path + str(k) + '.bmp';
        img_path = os.path.join(train_dir, path)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Error: Failed to read {img_path}")
            continue
        img = cv2.resize(img, (256, 256))
        img = np.expand_dims(img, axis=-1)

        images.append(img)
        labels.append(j)

# %%
images = np.array(images)
labels = np.array(labels)

# %%
# Create a CNN model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        36928
#
#  flatten (Flatten)           (None, 230400)            0
#
#  dense (Dense)               (None, 64)                14745664
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 14,802,058
# Trainable params: 14,802,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(images, 
                    labels,
                    epochs=30)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 14s 45ms/step - loss: 167.8086 - accuracy: 0.1163
# Epoch 2/30
# 25/25 [==============================] - 1s 44ms/step - loss: 1.9557 - accuracy: 0.3250
# Epoch 3/30
# 25/25 [==============================] - 1s 44ms/step - loss: 1.1086 - accuracy: 0.6137
# Epoch 4/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.8650 - accuracy: 0.6950
# Epoch 5/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.7662 - accuracy: 0.7300
# Epoch 6/30
# 25/25 [==============================] - 1s 44ms/step - loss: 0.7970 - accuracy: 0.7287
# Epoch 7/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.6810 - accuracy: 0.8000
# Epoch 8/30
# 25/25 [==============================] - 1s 46ms/step - loss: 0.8446 - accuracy: 0.7625
# Epoch 9/30
# 25/25 [==============================] - 1s 46ms/step - loss: 0.7119 - accuracy: 0.7700
# Epoch 10/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.6827 - accuracy: 0.8500
# Epoch 11/30
# 25/25 [==============================] - 1s 44ms/step - loss: 0.7554 - accuracy: 0.8375
# Epoch 12/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.5238 - accuracy: 0.8725
# Epoch 13/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.2641 - accuracy: 0.9413
# Epoch 14/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.1490 - accuracy: 0.9737
# Epoch 15/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.0946 - accuracy: 0.9837
# Epoch 16/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.0358 - accuracy: 0.9937
# Epoch 17/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.0274 - accuracy: 0.9950
# Epoch 18/30
# 25/25 [==============================] - 1s 45ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 19/30
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 20/30
# 25/25 [==============================] - 1s 45ms/step - loss: 8.1626e-04 - accuracy: 1.0000
# Epoch 21/30
# 25/25 [==============================] - 1s 45ms/step - loss: 4.2437e-04 - accuracy: 1.0000
# Epoch 22/30
# 25/25 [==============================] - 1s 45ms/step - loss: 2.9747e-04 - accuracy: 1.0000
# Epoch 23/30
# 25/25 [==============================] - 1s 45ms/step - loss: 2.4116e-04 - accuracy: 1.0000
# Epoch 24/30
# 25/25 [==============================] - 1s 45ms/step - loss: 2.0474e-04 - accuracy: 1.0000
# Epoch 25/30
# 25/25 [==============================] - 1s 45ms/step - loss: 1.7793e-04 - accuracy: 1.0000
# Epoch 26/30
# 25/25 [==============================] - 1s 45ms/step - loss: 1.5959e-04 - accuracy: 1.0000
# Epoch 27/30
# 25/25 [==============================] - 1s 45ms/step - loss: 1.4033e-04 - accuracy: 1.0000
# Epoch 28/30
# 25/25 [==============================] - 1s 45ms/step - loss: 1.2736e-04 - accuracy: 1.0000
# Epoch 29/30
# 25/25 [==============================] - 1s 45ms/step - loss: 1.1770e-04 - accuracy: 1.0000
# Epoch 30/30
# 25/25 [==============================] - 1s 45ms/step - loss: 1.0830e-04 - accuracy: 1.0000

# %%
model.save('/content/drive/MyDrive/Fingerprint/FVC2000_DB4_B/CNN.h5')

# %%
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
score = model.evaluate(images, labels, verbose=0)
print('accuracy:', score[1])
# Out:
# accuracy: 1.0
